# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
# %matplotlib inline

# %%
wtype = input('What weather type: ')
num_pts = input('How many data points: ')
# Out:
# What weather type: temp
# How many data points: 4320

# %%
data = {'temp':'1','press':'3'}
url1='https://thingspeak.com/channels/1733232/fields/'
url2 = data[wtype]
url3 = '.csv?results='
url4 = str(num_pts)
#url = 'https://thingspeak.com/channels/1733232/fields/[wtype].csv?results=[num_pts]'
url = url1+url2+url3+url4

# %%
plt.rcParams["figure.figsize"] = (30,10)
df = pd.read_csv(url)

# %%
df.tail()
# Out:
#                    created_at  entry_id  field1
# 4315  2022-08-14 10:03:04 UTC    259746   29.58
# 4316  2022-08-14 10:04:04 UTC    259747   29.58
# 4317  2022-08-14 10:05:04 UTC    259748   29.58
# 4318  2022-08-14 10:06:05 UTC    259749   29.58
# 4319  2022-08-14 10:07:05 UTC    259750   29.58

# %%
plt.plot(df['field1'],color='#f68923')
plt.savefig('temp.png')

# %%
from pandas import read_excel
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
# %matplotlib inline
my_sheet = 'Data Firebase' # change it to your sheet name, you can find your sheet name at the bottom left of your excel file
file_name = 'F:\A Seismologi\Firebase Data Suhu Thingspeak.xlsx' # change it to the name of your excel file
df = read_excel(file_name, sheet_name = my_sheet)
print(df.tail()) # shows headers with top 5 rows
# Out:
#                created_at  entry_id  field1      field3  status
# 29353 2022-08-12 06:36:56     29354   28.85  1012.16266   200.0
# 29354 2022-08-12 06:37:56     29355   28.86  1012.18219   200.0
# 29355 2022-08-12 06:38:57     29356   28.86  1012.18268   200.0
# 29356 2022-08-12 06:39:57     29357   28.86  1012.21228   200.0
# 29357 2022-08-12 06:41:03     29358   28.86  1012.23975   200.0

# %%
plt.rcParams["figure.figsize"] = (20,7)
plt.plot(df['field1'],color='#f68923')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (30,10)
file_name = 'https://thingspeak.com/channels/1733232/fields/temp.csv'
df = pd.read_csv(file_name)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 3>()
#       1 plt.rcParams["figure.figsize"] = (30,10)
#       2 file_name = 'https://thingspeak.com/channels/1733232/fields/temp.csv'
# ----> 3 df = pd.read_csv(file_name)
#
# File E:\Anaconda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.tail()
# Out:
#         type  id  name description  latitude  longitude field1 field3  \
# 7   dateTime NaN  None        None       NaN        NaN   None   None
# 8   dateTime NaN  None        None       NaN        NaN   None   None
# 9       None NaN  None        None       NaN        NaN   None   None
# 10   integer NaN  None        None       NaN        NaN   None   None
# 11     array NaN  None        None       NaN        NaN   None   None
#
#               created-at            updated-at  elevation  last-entry-id  feed
# 7   2022-05-12T11:22:05Z                  None        NaN            NaN   NaN
# 8                   None  2022-07-19T03:15:28Z        NaN            NaN   NaN
# 9                   None                  None       19.0            NaN   NaN
# 10                  None                  None        NaN       259746.0   NaN
# 11                  None                  None        NaN            NaN   NaN

# %%
plt.plot(df['field1'],color='#f68923')
